# %%
# importando módulos

# tratamento de dados
import pandas as pd
import numpy as np
import statistics

# gráficos
import matplotlib.pyplot as plt

# statsmodels (regressão)
import statsmodels.api as sm

# sklearn (separação de datasets treino e teste)
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('family_income_expenditure.csv')

# %%
df.head()
# Out:
#    Total Household Income Region  Total Food Expenditure  \
# 0                  480332    CAR                  117848
# 1                  198235    CAR                   67766
# 2                   82785    CAR                   61609
# 3                  107589    CAR                   78189
# 4                  189322    CAR                   94625
#
#   Main Source of Income  Agricultural Household indicator  \
# 0         Wage/Salaries                                 0
# 1         Wage/Salaries                                 0
# 2         Wage/Salaries                                 1
# 3         Wage/Salaries                                 0
# 4         Wage/Salaries                                 0
#
#    Bread and Cereals Expenditure  Total Rice Expenditure  Meat Expenditure  \
# 0                          42140                   38300             24676
# 1                          17329                   13008             17434
# ...

# %%
df.tail()
# Out:
#        Total Household Income              Region  Total Food Expenditure  \
# 41539                  119773  XII - SOCCSKSARGEN                   44875
# 41540                  137320  XII - SOCCSKSARGEN                   31157
# 41541                  133171  XII - SOCCSKSARGEN                   45882
# 41542                  129500  XII - SOCCSKSARGEN                   81416
# 41543                  128598  XII - SOCCSKSARGEN                   78195
#
#             Main Source of Income  Agricultural Household indicator  \
# 41539  Enterpreneurial Activities                                 1
# 41540  Enterpreneurial Activities                                 1
# 41541  Enterpreneurial Activities                                 2
# 41542  Enterpreneurial Activities                                 1
# 41543  Enterpreneurial Activities                                 1
#
#        Bread and Cereals Expenditure  Total Rice Expenditure  \
# ...

# %%
df.shape
# Out:
# (41544, 60)

# %%
df.columns
# Out:
# Index(['Total Household Income', 'Region', 'Total Food Expenditure',
#        'Main Source of Income', 'Agricultural Household indicator',
#        'Bread and Cereals Expenditure', 'Total Rice Expenditure',
#        'Meat Expenditure', 'Total Fish and  marine products Expenditure',
#        'Fruit Expenditure', 'Vegetables Expenditure',
#        'Restaurant and hotels Expenditure', 'Alcoholic Beverages Expenditure',
#        'Tobacco Expenditure', 'Clothing, Footwear and Other Wear Expenditure',
#        'Housing and water Expenditure', 'Imputed House Rental Value',
#        'Medical Care Expenditure', 'Transportation Expenditure',
#        'Communication Expenditure', 'Education Expenditure',
#        'Miscellaneous Goods and Services Expenditure',
#        'Special Occasions Expenditure', 'Crop Farming and Gardening expenses',
#        'Total Income from Entrepreneurial Acitivites', 'Household Head Sex',
#        'Household Head Age', 'Household Head Marital Status',
# ...

# %%
df['Medical Care Expenditure'].describe()
# Out:
# count    4.154400e+04
# mean     7.160231e+03
# std      2.690200e+04
# min      0.000000e+00
# 25%      3.000000e+02
# 50%      1.125000e+03
# 75%      4.680000e+03
# max      1.049275e+06
# Name: Medical Care Expenditure, dtype: float64

# %%
medical_care = df['Medical Care Expenditure']
medical_care
# Out:
# 0        3457
# 1        3520
# 2          70
# 3          60
# 4         140
#          ...
# 41539     294
# 41540     890
# 41541     540
# 41542     314
# 41543     330
# Name: Medical Care Expenditure, Length: 41544, dtype: int64

# %%
confianca = 0.95

# %%
erro_maximo = 500

# %%
medical_care.describe
# Out:
# <bound method NDFrame.describe of 0        3457
# 1        3520
# 2          70
# 3          60
# 4         140
#          ...
# 41539     294
# 41540     890
# 41541     540
# 41542     314
# 41543     330
# Name: Medical Care Expenditure, Length: 41544, dtype: int64>

# %%
desv_pad_pop = statistics.pstdev(medical_care)

# %%
erro = erro_maximo/desv_pad_pop
erro
# Out:
# 0.018586200860467722

# %%
def tamanhoAmostra(erro,N):
    
    n = (N / (1 + (N*(erro**2))))

    return (n)


N_ = 41543  

print(tamanhoAmostra(erro, N_))
# Out:
# 2706.225868885098

# %%
desv_pad_pop
# Out:
# 26901.678495441454

# %%
#  Para um nível de confiança de 95%, Z = 1.96

Z = 1.96

# %%
tamanho_da_amostra = ((Z * desv_pad_pop)/ erro_maximo)**2
tamanho_da_amostra
# Out:
# 11120.668380152994

# %%
tamanho_da_amostra = np.ceil(tamanho_da_amostra)
tamanho_da_amostra
# Out:
# 11121.0

# %%
novo_df = df[1:11122]
novo_df
# Out:
#        Total Household Income             Region  Total Food Expenditure  \
# 1                      198235                CAR                   67766
# 2                       82785                CAR                   61609
# 3                      107589                CAR                   78189
# 4                      189322                CAR                   94625
# 5                      152883                CAR                   73326
# ...                       ...                ...                     ...
# 11117                  195680  XI - Davao Region                   80614
# 11118                  374850  XI - Davao Region                  120337
# 11119                  653300  XI - Davao Region                  201179
# 11120                  506065  XI - Davao Region                  101931
# 11121                  407025  XI - Davao Region                   76321
#
#          Main Source of Income  Agricultural Household indicator  \
# ...

# %%
novo_df.columns
# Out:
# Index(['Total Household Income', 'Region', 'Total Food Expenditure',
#        'Main Source of Income', 'Agricultural Household indicator',
#        'Bread and Cereals Expenditure', 'Total Rice Expenditure',
#        'Meat Expenditure', 'Total Fish and  marine products Expenditure',
#        'Fruit Expenditure', 'Vegetables Expenditure',
#        'Restaurant and hotels Expenditure', 'Alcoholic Beverages Expenditure',
#        'Tobacco Expenditure', 'Clothing, Footwear and Other Wear Expenditure',
#        'Housing and water Expenditure', 'Imputed House Rental Value',
#        'Medical Care Expenditure', 'Transportation Expenditure',
#        'Communication Expenditure', 'Education Expenditure',
#        'Miscellaneous Goods and Services Expenditure',
#        'Special Occasions Expenditure', 'Crop Farming and Gardening expenses',
#        'Total Income from Entrepreneurial Acitivites', 'Household Head Sex',
#        'Household Head Age', 'Household Head Marital Status',
# ...

# %%
analise_descritiva_novo_dataset = novo_df._get_numeric_data().describe()
analise_descritiva_novo_dataset
# Out:
#        Total Household Income  Total Food Expenditure  \
# count            1.112100e+04            11121.000000
# mean             2.565760e+05            87918.904505
# std              3.051342e+05            52365.533735
# min              1.128500e+04             5638.000000
# 25%              1.133390e+05            53308.000000
# 50%              1.773760e+05            76530.000000
# 75%              3.066360e+05           109961.000000
# max              1.181599e+07           827565.000000
#
#        Agricultural Household indicator  Bread and Cereals Expenditure  \
# count                      11121.000000                   11121.000000
# mean                           0.174355                   25624.854869
# std                            0.379431                   15277.633854
# min                            0.000000                       0.000000
# 25%                            0.000000                   16839.000000
# ...
